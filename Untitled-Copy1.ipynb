# %% [markdown]
# ![OIP.jpg](attachment:OIP.jpg)

# %% [markdown]
# Microsoft Movie Studio Analysis
#
#
# Project Overview
#
# This project is about Microsoft Movie Analysis on their new movie studio. This will help and give insigtsto the best and trending movies that microsoft should leverage in, in the already versatile and dynamic industry.
# The project explores different datasets containing information about movies to determine the best films at the box office currently.
#
#
# Objectives
#
# 1.Analyse the new and and top movies that microsoft should venture in to be able to perform well in the industry as a new entrant
#
# 2.Compare different genres and the perfomance rating to be able to advise Microsoft on the best movie genres in the market.
#
# 3.Increase market presence where microsoft will be able to offer many solutions in one including entertainment to its customer as well as make profits, and this will be obtained by analysing box office grossings of various movies.

# %% [markdown]
# Data Loading and Inspection
#
# Data Understanding
# The dataset used for this anaysis was downloaded from different box offices. The data was was acquired from;
# https://www.boxofficemojo.com/
# https://www.imdb.com/
# https://www.rottentomatoes.com/
# https://www.themoviedb.org/
# https://www.the-numbers.com/
# .
#
# Data dictionary about movies:
#
# 1.movie_id: This is the primary key used to identifies all movies
# 2.primary_title: This is the original movie title the movie was given
# 3.start_year: This is the year the movie started production
# 4.runtime_minutes: This is the count of minutes in each movie
# 5.genres: This is the the classification of the movie
# 6.averagerating: This is the rating collected over the continent from viewers
# 7.numvotes: This is the number of people who voted the movies and their count was used to generate ratings
# 8.title: This is the title the movie was produced with
# studio: This is the studio in which each movie was produced
# 9.domestic_gross: This is the amount of money collected from each sell of movies in the country of origin
# 10.foreign_gross: This is the amount of money collected from each sell of movies in the country of origin
# 11.year: This is the year the movie was produced

# %%
# Loading the imports
import pandas as pd
import numpy as np
import sqlite3
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
a = r"C:\Users\ISABEL\Desktop\DSF_PT6\Phase_1\Project\zippedData\bom.movie_gross.csv.gz"
bom_movie_gross = pd.read_csv(a)
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#check te data information such as type and missing values
bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# There are missing values on foreign gross, domestic gross and studio

# %%
b = r"C:\Users\ISABEL\Desktop\DSF_PT6\Phase_1\Project\zippedData\imdb.title.basics.csv.gz"
imdb_title_basics = pd.read_csv(b)
imdb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# Only runtime_minutes original_title and genres has nmissing values

# %%
c = r"C:\Users\ISABEL\Desktop\DSF_PT6\Phase_1\Project\zippedData\imdb.title.ratings.csv.gz"
imdb_title_ratings = pd.read_csv(c)
imdb_title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdb_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# This data set has no missing values

# %%
#Dropping all missing values

#merged_df = pd.merge(directors_df, writers_df, on='movie_id', how='outer', suffixes=('_director', '_writer'))
merged_df = pd.merge(imdb_title_basics, imdb_title_ratings, on = "tconst", how='outer')
merged_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0      77.0
# 1        2019            114.0       Biography,Drama            7.2      43.0
# 2        2018            122.0                 Drama            6.9    4517.0
# 3        2018              NaN          Comedy,Drama            6.1      13.0
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5     119.0

# %%
merged_df.rename(columns={'primary_title': 'title'}, inplace=True)

# %%
final_merged_df = pd.merge(merged_df, bom_movie_gross, on = "title", how='outer')
final_merged_df.head()
# Out:
#       tconst                            title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes  \
# 0      2013.0            175.0    Action,Crime,Drama            7.0      77.0
# 1      2019.0            114.0       Biography,Drama            7.2      43.0
# 2      2018.0            122.0                 Drama            6.9    4517.0
# 3      2018.0              NaN          Comedy,Drama            6.1      13.0
# 4      2017.0             80.0  Comedy,Drama,Fantasy            6.5     119.0
#
#   studio  domestic_gross foreign_gross  year
# 0    NaN             NaN           NaN   NaN
# 1    NaN             NaN           NaN   NaN
# 2    NaN             NaN           NaN   NaN
# 3    NaN             NaN           NaN   NaN
# 4    NaN             NaN           NaN   NaN

# %%
final_merged_df.tail()
# Out:
#        tconst                         title original_title  start_year  \
# 146922    NaN                 Hannah (2018)            NaN         NaN
# 146923    NaN  Furious (Legend of Kolovrat)            NaN         NaN
# 146924    NaN   Edward II (2018 re-release)            NaN         NaN
# 146925    NaN                      El Pacto            NaN         NaN
# 146926    NaN                      The Swan            NaN         NaN
#
#         runtime_minutes genres  averagerating  numvotes      studio  \
# 146922              NaN    NaN            NaN       NaN         PDF
# 146923              NaN    NaN            NaN       NaN     CARUSEL
# 146924              NaN    NaN            NaN       NaN          FM
# 146925              NaN    NaN            NaN       NaN        Sony
# 146926              NaN    NaN            NaN       NaN  Synergetic
#
#         domestic_gross foreign_gross    year
# 146922         11700.0           NaN  2018.0
# 146923         10000.0           NaN  2018.0
# 146924          4800.0           NaN  2018.0
# 146925          2500.0           NaN  2018.0
# 146926          2400.0           NaN  2018.0

# %%
final_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146927 entries, 0 to 146926
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146146 non-null  object
#  1   title            146927 non-null  object
#  2   original_title   146125 non-null  object
#  3   start_year       146146 non-null  float64
#  4   runtime_minutes  114407 non-null  float64
#  5   genres           140738 non-null  object
#  6   averagerating    73858 non-null   float64
#  7   numvotes         73858 non-null   float64
#  8   studio           4142 non-null    object
#  9   domestic_gross   4112 non-null    float64
#  10  foreign_gross    2516 non-null    object
#  11  year             4147 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 14.6+ MB

# %%
final_merged_df.isna().sum()


#there are four columns with huge missing data but i will not drop the colums because i will need
#the columns for comlete analysis
# Out:
# tconst                781
# title                   0
# original_title        802
# start_year            781
# runtime_minutes     32520
# genres               6189
# averagerating       73069
# numvotes            73069
# studio             142785
# domestic_gross     142815
# foreign_gross      144411
# year               142780
# dtype: int64

# %%
final_merged_df.isna().mean() #the %ge of missing values on average rating and number of votes
                #is huge but the two columns are very necessary and cannot be dropped
# Out:
# tconst             0.005316
# title              0.000000
# original_title     0.005458
# start_year         0.005316
# runtime_minutes    0.221334
# genres             0.042123
# averagerating      0.497315
# numvotes           0.497315
# studio             0.971809
# domestic_gross     0.972013
# foreign_gross      0.982876
# year               0.971775
# dtype: float64

# %%
# this has dropped all missing values 
final_merged_df.dropna(inplace=True) 
final_merged_df.head()
# Out:
#        tconst                            title  \
# 58  tt0337692                      On the Road
# 61  tt4339118                      On the Road
# 63  tt5647250                      On the Road
# 70  tt0359950  The Secret Life of Walter Mitty
# 74  tt0365907      A Walk Among the Tombstones
#
#                      original_title  start_year  runtime_minutes  \
# 58                      On the Road      2012.0            124.0
# 61                      On the Road      2014.0             89.0
# 63                      On the Road      2016.0            121.0
# 70  The Secret Life of Walter Mitty      2013.0            114.0
# 74      A Walk Among the Tombstones      2014.0            114.0
#
#                      genres  averagerating  numvotes studio  domestic_gross  \
# 58  Adventure,Drama,Romance            6.1   37886.0    IFC        744000.0
# 61                    Drama            6.0       6.0    IFC        744000.0
# 63                    Drama            5.7     127.0    IFC        744000.0
# 70   Adventure,Comedy,Drama            7.3  275300.0    Fox      58200000.0
# 74       Action,Crime,Drama            6.5  105116.0   Uni.      26300000.0
#
#    foreign_gross    year
# 58       8000000  2012.0
# 61       8000000  2012.0
# 63       8000000  2012.0
# 70     129900000  2013.0
# 74      26900000  2014.0

# %%
# there are no missing values 
final_merged_df.isna().sum()
# Out:
# tconst             0
# title              0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# averagerating      0
# numvotes           0
# studio             0
# domestic_gross     0
# foreign_gross      0
# year               0
# dtype: int64

# %%
final_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1767 entries, 58 to 141254
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           1767 non-null   object
#  1   title            1767 non-null   object
#  2   original_title   1767 non-null   object
#  3   start_year       1767 non-null   float64
#  4   runtime_minutes  1767 non-null   float64
#  5   genres           1767 non-null   object
#  6   averagerating    1767 non-null   float64
#  7   numvotes         1767 non-null   float64
#  8   studio           1767 non-null   object
#  9   domestic_gross   1767 non-null   float64
#  10  foreign_gross    1767 non-null   object
#  11  year             1767 non-null   float64
# dtypes: float64(6), object(6)
# memory usage: 179.5+ KB

# %%
final_merged_df.drop(columns = ["original_title","start_year"],inplace=True)
final_merged_df

#i dropped the original_title as i thought it was similar/almost similar to primary_title,
#as for the numvotes, i will use the rating instead i do not need the number of the votes
# Out:
#            tconst                            title  runtime_minutes  \
# 58      tt0337692                      On the Road            124.0
# 61      tt4339118                      On the Road             89.0
# 63      tt5647250                      On the Road            121.0
# 70      tt0359950  The Secret Life of Walter Mitty            114.0
# 74      tt0365907      A Walk Among the Tombstones            114.0
# ...           ...                              ...              ...
# 128429  tt7752454            Detective Chinatown 2            121.0
# 128826  tt7784604                       Hereditary            127.0
# 131968  tt8097306                    Nobody's Fool            110.0
# 134858  tt8404272           How Long Will I Love U            101.0
# 141254  tt9151704        Burn the Stage: The Movie             84.0
#
#                          genres  averagerating  numvotes     studio  \
# 58      Adventure,Drama,Romance            6.1   37886.0        IFC
# 61                        Drama            6.0       6.0        IFC
# 63                        Drama            5.7     127.0        IFC
# 70       Adventure,Comedy,Drama            7.3  275300.0        Fox
# 74           Action,Crime,Drama            6.5  105116.0       Uni.
# ...                         ...            ...       ...        ...
# 128429    Action,Comedy,Mystery            6.1    1250.0         WB
# 128826     Drama,Horror,Mystery            7.3  151571.0        A24
# 131968     Comedy,Drama,Romance            4.6    3618.0       Par.
# 134858                  Romance            6.5     607.0      WGUSA
# 141254        Documentary,Music            8.8    2067.0  Trafalgar
#
#         domestic_gross foreign_gross    year
# 58            744000.0       8000000  2012.0
# 61            744000.0       8000000  2012.0
# 63            744000.0       8000000  2012.0
# 70          58200000.0     129900000  2013.0
# 74          26300000.0      26900000  2014.0
# ...                ...           ...     ...
# 128429       2000000.0     542100000  2018.0
# 128826      44100000.0      35300000  2018.0
# 131968      31700000.0       1800000  2018.0
# 134858        747000.0      82100000  2018.0
# 141254       4200000.0      16100000  2018.0
#
# [1767 rows x 10 columns]

# %%
final_merged_df.rename(columns={'tconst': 'movie_id'}, inplace=True)

# %%
# changing the name of the data frame for easy refernce
df = final_merged_df
df
# Out:
#          movie_id                            title  runtime_minutes  \
# 58      tt0337692                      On the Road            124.0
# 61      tt4339118                      On the Road             89.0
# 63      tt5647250                      On the Road            121.0
# 70      tt0359950  The Secret Life of Walter Mitty            114.0
# 74      tt0365907      A Walk Among the Tombstones            114.0
# ...           ...                              ...              ...
# 128429  tt7752454            Detective Chinatown 2            121.0
# 128826  tt7784604                       Hereditary            127.0
# 131968  tt8097306                    Nobody's Fool            110.0
# 134858  tt8404272           How Long Will I Love U            101.0
# 141254  tt9151704        Burn the Stage: The Movie             84.0
#
#                          genres  averagerating  numvotes     studio  \
# 58      Adventure,Drama,Romance            6.1   37886.0        IFC
# 61                        Drama            6.0       6.0        IFC
# 63                        Drama            5.7     127.0        IFC
# 70       Adventure,Comedy,Drama            7.3  275300.0        Fox
# 74           Action,Crime,Drama            6.5  105116.0       Uni.
# ...                         ...            ...       ...        ...
# 128429    Action,Comedy,Mystery            6.1    1250.0         WB
# 128826     Drama,Horror,Mystery            7.3  151571.0        A24
# 131968     Comedy,Drama,Romance            4.6    3618.0       Par.
# 134858                  Romance            6.5     607.0      WGUSA
# 141254        Documentary,Music            8.8    2067.0  Trafalgar
#
#         domestic_gross foreign_gross    year
# 58            744000.0       8000000  2012.0
# 61            744000.0       8000000  2012.0
# 63            744000.0       8000000  2012.0
# 70          58200000.0     129900000  2013.0
# 74          26300000.0      26900000  2014.0
# ...                ...           ...     ...
# 128429       2000000.0     542100000  2018.0
# 128826      44100000.0      35300000  2018.0
# 131968      31700000.0       1800000  2018.0
# 134858        747000.0      82100000  2018.0
# 141254       4200000.0      16100000  2018.0
#
# [1767 rows x 10 columns]

# %%
df['total_gross'] = (df['domestic_gross'] + df['foreign_gross'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c67a152ad09a> in <module>
# ----> 1 df['total_gross'] = (df['domestic_gross'] + df['foreign_gross'])
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      90         if mask.any():
#      91             with np.errstate(all="ignore"):
# ---> 92                 result[mask] = op(xrav[mask], yrav[mask])
#      93
#      94     else:
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
# Convert the two colums from float to intergers
df['numvotes'] = df['numvotes'].astype(int)
df['year'] = df['year'].astype(int)
df['foreign_gross'] = df['foreign_gross'].astype(int)

# %%
df['foreign_gross'].fillna(0, inplace=True)
df['domestic_gross'].fillna(0, inplace=True)
df['foreign_gross'] = pd.to_numeric(df['foreign_gross'], errors='coerce').fillna(0)

# %%
df.duplicated().sum()
# there are no duplicates in the data set

# %%
df.drop(columns = ["domestic_gross","foreign_gross"],inplace=True)

# %%
df.info()

# %%
# Plotting a bar graph of the most watched genres
plt.figure(figsize=(12, 6))
genre_counts = df['genres'].str.split(',').explode().value_counts()
sns.barplot(x=genre_counts.values, y=genre_counts.index, palette="viridis")
plt.title('Most Watched Genres')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.show()

# %%
# Sort the DataFrame by 'numvotes' column in descending order
sorted_movies = highly_rated_movies.sort_values(by='numvotes', ascending=False)

# Create the bar plot
sns.set_palette("pastel")
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.barplot(x="title", y="numvotes", data=sorted_movies, ci=False, capsize=0.2, errwidth=1.5, palette="pastel", dodge=True, saturation=0.8, width=0.8)

# Add horizontal grid lines
ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Set labels and title
ax.set_xlabel("Movie Title", fontsize=12)
ax.set_ylabel("Number of Votes", fontsize=12)
plt.title("Number of Votes for Highly Rated Movies (Sorted)", fontsize=16)

# Adjust tick parameters
plt.xticks(rotation=45, ha="right")
ax.tick_params(axis="x", labelsize=10)
ax.tick_params(axis="y", labelsize=10)

# Show the plot
plt.show()

# %%
plt.figure(figsize = (20, 3))
plt.subplot(2,2,1)
sns.distplot(df['runtime_minutes'])
plt.title('Average_runtime_minutes')
plt.subplot(2,2,2)
sns.distplot(df['averagerating'], color= "green")
plt.title('Average_rating')
plt.subplot(2,2,3)
sns.boxplot(df['runtime_minutes'],orient= "h")
plt.subplot(2,2,4)
sns.boxplot(df['averagerating'],orient= "h")
#plt.title('Average_runtime_minutes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Selecting the size of the plot
plt.figure(figsize=(12,10),facecolor='w', edgecolor='k')

# Plotting the graph
rotten_tomatoes.plot(kind='barh',color='blue')

# Setting the label of the x axis
plt.xlabel("Box Office Income")

# Setting the label of the y axis
plt.ylabel("Genre")
plt.title('Genre Aganist Box office',fontsize=40)
# Setting the font size of the yticks
plt.yticks(fontsize=15);
